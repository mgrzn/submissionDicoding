# %% [markdown]
# # Proyek Analisis Data: E-commerce-public-dataset
# - **Nama:** Magrozan Qobus Zaidan
# - **Email:** grozan.14@gmail.com
# - **ID Dicoding:** MAGROZAN QOBUS ZAIDAN

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Apa produk yang memiliki penjualan tertinggi dan terendah?
# - Bagaimana tingkat kepuasan pembeli?
# - Dimana letak geografis pembeli terbanyak ?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import urllib
import seaborn as sns
import matplotlib.image as mpimg
from scipy import stats

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# !unzip '/content/drive/MyDrive/Bangkit/E-commerce-public-dataset.zip' -d '/content/extracted_data'
# Out:
# Mounted at /content/drive
# Archive:  /content/drive/MyDrive/Bangkit/E-commerce-public-dataset.zip
#   inflating: /content/extracted_data/E-Commerce Public Dataset/customers_dataset.csv
#   inflating: /content/extracted_data/E-Commerce Public Dataset/geolocation_dataset.csv
#  extracting: /content/extracted_data/E-Commerce Public Dataset/New Text Document.txt
#   inflating: /content/extracted_data/E-Commerce Public Dataset/order_items_dataset.csv
#   inflating: /content/extracted_data/E-Commerce Public Dataset/order_payments_dataset.csv
#   inflating: /content/extracted_data/E-Commerce Public Dataset/order_reviews_dataset.csv
#   inflating: /content/extracted_data/E-Commerce Public Dataset/orders_dataset.csv
#   inflating: /content/extracted_data/E-Commerce Public Dataset/product_category_name_translation.csv
#   inflating: /content/extracted_data/E-Commerce Public Dataset/products_dataset.csv
#   inflating: /content/extracted_data/E-Commerce Public Dataset/sellers_dataset.csv

# %%
data_dir = "/content/extracted_data/E-Commerce Public Dataset/"

orders = pd.read_csv(data_dir + 'orders_dataset.csv')
items = pd.read_csv(data_dir + 'order_items_dataset.csv')
products = pd.read_csv(data_dir + 'products_dataset.csv')
payments = pd.read_csv(data_dir + 'order_payments_dataset.csv')
reviews = pd.read_csv(data_dir + 'order_reviews_dataset.csv')
customers = pd.read_csv(data_dir + 'customers_dataset.csv')
sellers = pd.read_csv(data_dir + 'sellers_dataset.csv')
geolocation = pd.read_csv(data_dir + 'geolocation_dataset.csv')
category = pd.read_csv(data_dir + 'product_category_name_translation.csv')

data = {'orders': orders,
        'items': items,
        'products': products,
        'payments': payments,
        'reviews': reviews,
        'customers': customers,
        'sellers': sellers,
        'geo': geolocation,
        'category': category}

# %%
data['customers'].head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
data['reviews'].head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
data['payments'].head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
data['products'].head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
data['category'].head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
data['sellers'].head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
data['geo'].head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
data['orders'].head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
data['items'].head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# Membuat function untuk menganalisis tabel yang berisi info tabel, missing value yang ada di tabel, data duplikat yang ada di tabel, deskripsi dari tabel

# %%
def analisis_data(df):
    # Print info table
    print(f"\n---Info Tabel---\n")
    df.info()

    # Print missing values table
    print(f"\n---Missing Value---\n")
    print(df.isna().sum())

    # Print duplicated values count
    print(f"\n---Jumlah Duplikat---\n")
    print(df.duplicated().sum())

    # Print table description
    print(f"\n---Deskripsi Tabel---\n")
    print(df.describe())

# %%
analisis_data(data['items'])
# Out:
# ---Info Tabel---
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB
#
# ---Missing Value---
#
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64
#
# ---Jumlah Duplikat---
#
# 0
#
# ---Deskripsi Tabel---
#
# ...

# %%
analisis_data(data['payments'])
# Out:
# ---Info Tabel---
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB
#
# ---Missing Value---
#
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64
#
# ---Jumlah Duplikat---
#
# 0
#
# ---Deskripsi Tabel---
#
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# ...

# %%
analisis_data(data['category'])
# Out:
# ---Info Tabel---
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB
#
# ---Missing Value---
#
# product_category_name            0
# product_category_name_english    0
# dtype: int64
#
# ---Jumlah Duplikat---
#
# 0
#
# ---Deskripsi Tabel---
#
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %%
analisis_data(data['reviews'])
# Out:
# ---Info Tabel---
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB
#
# ---Missing Value---
#
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64
#
# ---Jumlah Duplikat---
#
# 0
# ...

# %%
analisis_data(data['sellers'])
# Out:
# ---Info Tabel---
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB
#
# ---Missing Value---
#
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64
#
# ---Jumlah Duplikat---
#
# 0
#
# ---Deskripsi Tabel---
#
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# ...

# %%
analisis_data(data['geo'])
# Out:
# ---Info Tabel---
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB
#
# ---Missing Value---
#
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64
#
# ---Jumlah Duplikat---
#
# 261831
#
# ---Deskripsi Tabel---
#
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# ...

# %%
analisis_data(data['products'])
# Out:
# ---Info Tabel---
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB
#
# ---Missing Value---
#
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# ...

# %%
analisis_data(data['orders'])
# Out:
# ---Info Tabel---
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB
#
# ---Missing Value---
#
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# ...

# %%
analisis_data(data['customers'])
# Out:
# ---Info Tabel---
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB
#
# ---Missing Value---
#
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
#
# ---Jumlah Duplikat---
#
# 0
#
# ---Deskripsi Tabel---
#
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# ...

# %% [markdown]
# **Insight:**
# - Terdapat 261831 data duplikat di tabel geo
# - Kolom shipping_limit_date pada tabel items bukan tipe data object
# - tabel review memiliki 2 kolom missing value yaitu kolom : review_comment_tittle dan review_comment_massage
# Tipe data pada kolom dengan data date belum sesuai, masih berupa object
# - Tabel orders memiliki missing value pada kolom :
# order_approved_at
# order_delivered_carrier_date
# order_delivered_customer_date
# Tipe data pada kolom dengan data date belum sesuai, masih berupa object
# - tabel product memiliki missing value di semua kolom kecuale kolom product_id

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Menghapus data duplikat pada tabel geolocation

# %%
data['geo'] = data['geo'].drop_duplicates()

# %% [markdown]
# Mengubah tipe data kolom shipping_limit_date pada tabel items menjadi datetime

# %%
data['items']['shipping_limit_date'] = pd.to_datetime(data['items']['shipping_limit_date'])

# %% [markdown]
# Mengatasi missing value pada tabel reviews dengan mengisi nilai kosong pada kolom review_comment_title dan review_comment_message dengan "No Comment"

# %%
data['reviews']['review_comment_title'].fillna("No Comment", inplace=True)
data['reviews']['review_comment_message'].fillna("No Comment", inplace=True)

# %% [markdown]
# Mengubah tipe data kolom order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date pada tabel orders menjadi datetime

# %%
for column in ['order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date']:
  data['orders'][column] = pd.to_datetime(data['orders'][column], errors='coerce')

# %% [markdown]
# Mengatasi missing value pada tabel orders dengan menghapus baris yang memiliki missing value pada kolom order_approved_at, order_delivered_carrier_date, order_delivered_customer_date

# %%
data['orders'].dropna(subset=['order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date'], inplace=True)

# %% [markdown]
#  Menghapus kolom yang memiliki banyak missing value pada tabel products

# %%
data['products'].dropna(thresh=len(data['products']) * 0.5, axis=1, inplace=True)

# %% [markdown]
# Mengecek kembali missing value setelah cleaning data

# %%
for key, df in data.items():
  print(f"\n---Missing Value {key}---\n")
  print(df.isna().sum())
# Out:
# ---Missing Value orders---
#
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64
#
# ---Missing Value items---
#
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64
#
# ---Missing Value products---
#
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64
#
# ---Missing Value payments---
#
# ...

# %% [markdown]
# Menghapus baris yang memiliki missing value pada kolom product_category_name di tabel products

# %%
data['products'].dropna(subset=['product_category_name'], inplace=True)

# Mengecek kembali missing value setelah cleaning data
print(f"\n---Missing Value products---\n")
print(data['products'].isna().sum())
# Out:
# ---Missing Value products---
#
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              1
# product_length_cm             1
# product_height_cm             1
# product_width_cm              1
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
data['customers'].sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 38082  def6003502bb7701e2cdc0cb5af42cfe  f3e71989aaa365356d121d87129aa2ce
# 87009  73910c380c76a4dca24e4e6bfdad16e2  119cb28909c55bbc281118dd8a086906
# 16649  97efeb58e92886e9de1ab49ce06a8139  6c7c9cbd6becaa4a1822207f900cc0bb
# 88714  8578b195ef00d35534b548af9e9a152d  a7c9c27c939f750a01aabf3a014051d8
# 48140  4974be94784b655505e37fdb610a8e78  b4c4f3643e0a12224cf57abe82ecd677
#
#        customer_zip_code_prefix   customer_city customer_state
# 38082                      4014       sao paulo             SP
# 87009                     22713  rio de janeiro             RJ
# 16649                      9320            maua             SP
# 88714                      8410       sao paulo             SP
# 48140                     26535       nilopolis             RJ

# %%
data['customers'].describe(include='all')
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
data['customers'].customer_id.is_unique
# Out:
# True

# %%
data['customers'].groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %%
data['customers'].groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %% [markdown]
# **Insight:**
# - Customer terbanyak diketahui berasal dari sao paulo city dan sao paoulo state

# %% [markdown]
# ### Explore ...

# %%
data['orders'].sample(5)
# Out:
#                                order_id                       customer_id  \
# 21450  7416fee595e25348b79a5d82a55c725d  4ff01dfee89511e08ce1605b08142cb8
# 10900  34041ba8694b6808060aafda57f6075e  e98998055b4804137a020830903f93f2
# 4308   37e7875cdce5a9e5b3a692971f370151  3fecd6727aed19735e06945b7c3e49c9
# 50502  5f5a9ba3e0190ff4773314db075b930d  77e495840d1437dc483ce6e82182dbd4
# 16637  fee6682c7a195d411531745fdcd4d1db  36e3882c806ea8ab9c2b1981cb46c255
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 21450    delivered      2018-03-19 11:43:13 2018-03-19 11:55:32
# 10900    delivered      2017-03-20 18:33:07 2017-03-20 18:33:07
# 4308     delivered      2018-05-18 12:15:11 2018-05-18 13:05:53
# 50502    delivered      2017-08-22 19:39:56 2017-08-22 19:55:47
# 16637    delivered      2018-07-16 23:01:20 2018-07-16 23:15:20
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 21450          2018-03-21 19:16:35           2018-03-31 21:08:41
# ...

# %%
data['orders']['order_status'].describe()
# Out:
# count         96461
# unique            2
# top       delivered
# freq          96455
# Name: order_status, dtype: object

# %%
data['payments'].sample(5)
# Out:
#                                order_id  payment_sequential payment_type  \
# 86636  61b1dbc033920b4d291fe4a768eed1d0                   1  credit_card
# 78201  f14c04adfb43f42e0c17f11903c302d9                   1  credit_card
# 88856  f2be3946c5ae27518a65c37a05b914f9                   1       boleto
# 77362  224178696ac7ef9533253acd7653f158                   1  credit_card
# 48232  f175c06d9a1a1c98a7ba8dd83950718f                   1  credit_card
#
#        payment_installments  payment_value
# 86636                     3          32.72
# 78201                     5         138.63
# 88856                     1          65.09
# 77362                     2          61.13
# 48232                     3         131.29

# %%
data['payments'].groupby(by="payment_type").order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %% [markdown]
# merge customer dan orders

# %%
customers_orders_df = pd.merge(
    left=data['customers'],
    right=data['orders'],
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
customers_orders_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %% [markdown]
# Merge payments dan review

# %%
payments_reviews_df = pd.merge(
    left=data['payments'],
    right=data['reviews'],
    how="left",
    left_on="order_id",
    right_on="order_id"
)
payments_reviews_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
#
#    payment_installments  payment_value                         review_id  \
# 0                     8          99.33  4ce650e117a5b292bf5ea980a61eb61e
# 1                     1          24.39  ad2036caca61484fc435d7e673c020f2
# 2                     1          65.71  bcddfa0f7d2e54cfc74bae4f01b84d92
# 3                     8         107.78  c37a0e51e5df82bdb55d38ff0ffb6af3
# 4                     8         107.78  5bc7680443b4ef765fec11a8201eeb0c
#
#    review_score review_comment_title  \
# 0           1.0        Não recomendo
# ...

# %%
payments_reviews_df.sort_values(by="payment_value", ascending=False)
# Out:
#                                order_id  payment_sequential payment_type  \
# 52415  03caa2c082116e1d31e67e9ae3700499                   1  credit_card
# 34565  736e1922ae60d0d6a89247b851902527                   1       boleto
# 41660  0812eb902a67711a1cb742b3cdaa65ae                   1  credit_card
# 49871  fefacc66af859508bf1a7934eab1e97f                   1       boleto
# 86018  f5136e38d1a14a4dbd87dff67da82701                   1       boleto
# ...                                 ...                 ...          ...
# 78326  fa65dad1b0e818e3ccc5cb0e39231352                  13      voucher
# 51581  4637ca194b6387e2d538dc89b124b0ee                   1  not_defined
# 37030  fa65dad1b0e818e3ccc5cb0e39231352                  14      voucher
# 94953  c8c528189310eaa44a745b8d9d26908b                   1  not_defined
# 20031  8bcbe01d44d147f901cd3192671144db                   4      voucher
#
#        payment_installments  payment_value                         review_id  \
# ...

# %%
payments_reviews_df.groupby(by="payment_type").agg({
    "order_id": "nunique",
    "payment_value":  ["min", "max"]
})
# Out:
#              order_id payment_value
#               nunique           min       max
# payment_type
# boleto          19784         11.62   7274.88
# credit_card     76505          0.01  13664.08
# debit_card       1528         13.38   4445.50
# not_defined         3          0.00      0.00
# voucher          3866          0.00   3184.34

# %% [markdown]
# merge payment review dan customers orders

# %%
customers_df = pd.merge(
    left=customers_orders_df,
    right=payments_reviews_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %% [markdown]
# Merge product dan category

# %%
product_df = pd.merge(
    left=data['products'],
    right=data['category'],
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)
product_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
product_df.groupby(by="product_category_name").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name
# cama_mesa_banho           3029
# esporte_lazer             2867
# moveis_decoracao          2657
# beleza_saude              2444
# utilidades_domesticas     2335
# automotivo                1900
# informatica_acessorios    1639
# brinquedos                1411
# relogios_presentes        1329
# telefonia                 1134
# Name: product_id, dtype: int64

# %%
product_df.groupby(by="product_category_name_english").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name_english
# bed_bath_table           3029
# sports_leisure           2867
# furniture_decor          2657
# health_beauty            2444
# housewares               2335
# auto                     1900
# computers_accessories    1639
# toys                     1411
# watches_gifts            1329
# telephony                1134
# Name: product_id, dtype: int64

# %% [markdown]
# merge item dan sellers

# %%
item_seller_df = pd.merge(
    left=data['items'],
    right=data['sellers'],
    how="left",
    left_on="seller_id",
    right_on="seller_id"
)
item_seller_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  seller_zip_code_prefix  \
# 0 2017-09-19 09:45:35   58.90          13.29                   27277
# 1 2017-05-03 11:05:13  239.90          19.93                    3471
# ...

# %%
item_seller_df.groupby(by="seller_city").seller_id.nunique().sort_values(ascending=False).head(10)
# Out:
# seller_city
# sao paulo         694
# curitiba          127
# rio de janeiro     96
# belo horizonte     68
# ribeirao preto     52
# guarulhos          50
# ibitinga           49
# santo andre        45
# campinas           41
# maringa            40
# Name: seller_id, dtype: int64

# %%
item_seller_df.groupby(by="seller_state").seller_id.nunique().sort_values(ascending=False).head(10)
# Out:
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# Name: seller_id, dtype: int64

# %% [markdown]
# merge seller item dan product

# %%
sellers_df = pd.merge(
    left=product_df,
    right=item_seller_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
sellers_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
sellers_df.sort_values(by="price", ascending=False)
# Out:
#                              product_id              product_category_name  \
# 20259  489ae2aa008f021502940f251d4cce7f              utilidades_domesticas
# 72949  69c590f7ffc7bf8db97190b6cb6ed62e                                pcs
# 48844  1bdf5e6731585cf01aa8169c7028d6ad                              artes
# 70870  a6492cc69376c469ab6f61d8f44de961                    eletroportateis
# 31829  c3ed642d592594bb648ff4a04cee2747                    eletroportateis
# ...                                 ...                                ...
# 9217   270516a3f41dc035aa87d220228f844c                       beleza_saude
# 9218   270516a3f41dc035aa87d220228f844c                       beleza_saude
# 29223  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
# 29222  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
# 29224  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
#
# ...

# %%
sellers_df.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "price":  ["min", "max"]
})
# Out:
#                               order_id  price
#                                nunique    min      max
# product_category_name_english
# agro_industry_and_commerce         182  12.99  2990.00
# air_conditioning                   253  10.90  1599.00
# art                                202   3.50  6499.00
# arts_and_craftmanship               23   9.80   289.49
# audio                              350  14.90   598.99
# ...                                ...    ...      ...
# stationery                        2311   2.29  1693.00
# tablets_printing_image              79  14.90   889.99
# telephony                         4199   5.00  2428.00
# toys                              3886   4.90  1699.99
# watches_gifts                     5624   8.99  3999.90
#
# [71 rows x 3 columns]

# %%
data['geo'].sample(5)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 393071                        18602       -22.895755       -48.442071
# 866655                        84015       -25.080421       -50.166450
# 384670                        18135       -23.548729       -47.115181
# 6596                           1255       -23.544473       -46.683002
# 734894                        59056        -5.819118       -35.205081
#
#        geolocation_city geolocation_state
# 393071         botucatu                SP
# 866655     ponta grossa                PR
# 384670        sao roque                SP
# 6596          sao paulo                SP
# 734894            natal                RN

# %%
data['geo'].groupby('geolocation_zip_code_prefix').size().sort_values(ascending=False)
# Out:
# geolocation_zip_code_prefix
# 38400    779
# 35500    751
# 11680    727
# 11740    678
# 36400    627
#         ...
# 40024      1
# 39999      1
# 39955      1
# 39931      1
# 39888      1
# Length: 19015, dtype: int64

# %%
data['geo'][data['geo']['geolocation_zip_code_prefix'] == 24230].head()
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 470806                        24230       -22.911270       -43.105151
# 470807                        24230       -22.905032       -43.114682
# 470810                        24230       -22.909753       -43.101880
# 470816                        24230       -22.908945       -43.108600
# 470817                        24230       -22.906274       -43.103573
#
#        geolocation_city geolocation_state
# 470806          niterói                RJ
# 470807          niterói                RJ
# 470810          niteroi                RJ
# 470816          niteroi                RJ
# 470817          niteroi                RJ

# %% [markdown]
# merge all data

# %%
all_data = pd.merge(
    left=customers_df,
    right=sellers_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_data.head(20)
# Out:
#                          customer_id                customer_unique_id  \
# 0   06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1   18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2   4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3   b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4   4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 5   879864dab9bc3047522c92c82e1212b8  4c93744516667ad3b8f1fb645a3116a4
# 6   fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 7   5e274e7a0c3809e14aba7ad5aae0d407  57b2a98a409812fe9618067b6b8ebe4f
# 8   5adf08e34b2e993982a47070956c5c65  1175e95fb47ddff9de6b2b06188f7e0d
# 9   4b7139f34592b3a31687243a302fa75b  9afe194fb833f79e300e37e580171f22
# 10  9fb35e4ed6f0a14a4977cd9aea4042bb  2a7745e1ed516b289ed9b29c7d0539a5
# 11  5aa9e4fdd4dfd20959cad2d772509598  2a46fb94aef5cbeeb850418118cee090
# ...

# %%
all_data_df = all_data.drop_duplicates('order_id')

# %%
all_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96462 entries, 0 to 118467
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer_id                    96462 non-null  object
#  1   customer_unique_id             96462 non-null  object
#  2   customer_zip_code_prefix       96462 non-null  int64
#  3   customer_city                  96462 non-null  object
#  4   customer_state                 96462 non-null  object
#  5   order_id                       96461 non-null  object
#  6   order_status                   96461 non-null  object
#  7   order_purchase_timestamp       96461 non-null  datetime64[ns]
#  8   order_approved_at              96461 non-null  datetime64[ns]
#  9   order_delivered_carrier_date   96461 non-null  datetime64[ns]
#  10  order_delivered_customer_date  96461 non-null  datetime64[ns]
# ...

# %%
all_data.groupby(by="customer_state").agg({
    "order_id": "nunique",
    "payment_value": "sum"
}).sort_values(by="payment_value", ascending=False)
# Out:
#                 order_id  payment_value
# customer_state
# SP                 40489     7434958.12
# RJ                 12351     2694588.60
# MG                 11352     2287820.76
# RS                  5342     1108280.99
# PR                  4923     1034601.30
# BA                  3256      772423.42
# SC                  3547      768559.38
# GO                  1957      496426.61
# DF                  2080      424613.99
# ES                  1995      399201.58
# PE                  1593      361363.59
# CE                  1278      332168.11
# PA                   946      255327.31
# MT                   886      251859.09
# MA                   716      195191.60
# PB                   517      177320.00
# MS                   701      164556.97
# PI                   476      133729.03
# RN                   474      115203.08
# AL                   397      108727.76
# SE                   335       85694.32
# TO                   274       70780.74
# ...

# %%
all_data.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "review_score":  ["min", "max"]
})
# Out:
#                               order_id review_score
#                                nunique          min  max
# product_category_name_english
# agro_industry_and_commerce         177          1.0  5.0
# air_conditioning                   246          1.0  5.0
# art                                195          1.0  5.0
# arts_and_craftmanship               23          1.0  5.0
# audio                              348          1.0  5.0
# ...                                ...          ...  ...
# stationery                        2264          1.0  5.0
# tablets_printing_image              79          1.0  5.0
# telephony                         4092          1.0  5.0
# toys                              3804          1.0  5.0
# watches_gifts                     5493          1.0  5.0
#
# [71 rows x 3 columns]

# %% [markdown]
# save data ke path yang sudah ditentukan

# %%
output_csv_path = "drive/MyDrive/Bangkit/data_submission_analisis_data.csv"
all_data_df.to_csv(output_csv_path, index=False)

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Apa produk yang memiliki penjualan tertinggi dan terendah ?

# %%
sum_order_items_df = all_data.groupby("product_category_name_english")["product_id"].count().reset_index()
sum_order_items_df = sum_order_items_df.rename(columns={"product_id": "products"})
sum_order_items_df = sum_order_items_df.sort_values(by="products", ascending=False)

sum_order_items_df.head()
# Out:
#    product_category_name_english  products
# 7                 bed_bath_table     11813
# 43                 health_beauty      9818
# 65                sports_leisure      8789
# 39               furniture_decor      8639
# 15         computers_accessories      7962

# %%
sum_order_items_df.sort_values(by="products", ascending=True).head(5)
# Out:
#    product_category_name_english  products
# 61         security_and_services         2
# 29     fashion_childrens_clothes         7
# 11             cds_dvds_musicals        14
# 52                    la_cuisine        16
# 3          arts_and_craftmanship        24

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#068DA9", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="products", y="product_category_name_english", data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Produk paling banyak terjual", loc="center", fontsize=18)
ax[0].tick_params(axis ='y', labelsize=15)

sns.barplot(x="products", y="product_category_name_english", data=sum_order_items_df.sort_values(by="products", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Produk paling sedikit terjual", loc="center", fontsize=18)
ax[1].tick_params(axis='y', labelsize=15)

plt.suptitle("Apa produk yang memiliki penjualan tertinggi dan terendah ?", fontsize=20)
plt.show()
# Out:
# <ipython-input-70-e3f13043efb1>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="products", y="product_category_name_english", data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
# <ipython-input-70-e3f13043efb1>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="products", y="product_category_name_english", data=sum_order_items_df.sort_values(by="products", ascending=True).head(5), palette=colors, ax=ax[1])

# %% [markdown]
# Dari grafik diatas bisa kita liat bahwa penjualan tertinggi terdapat di produk bed_bath_table dan penjualan terendah terdapat pada produk security_and_services

# %% [markdown]
# ### Pertanyaan 2: Bagaimana tingkat kepuasan pembeli?

# %%
review_score_counts = all_data['review_score'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
plt.bar(review_score_counts.index, review_score_counts.values)
plt.xlabel('Review Score')
plt.ylabel('Jumlah Review')
plt.title('Tingkat Kepuasan Pembeli Berdasarkan Review Score')
plt.show()

print(all_data['review_score'].describe())
# Out:
# count    114628.000000
# mean          4.082048
# std           1.346297
# min           1.000000
# 25%           4.000000
# 50%           5.000000
# 75%           5.000000
# max           5.000000
# Name: review_score, dtype: float64

# %% [markdown]
# dari grafik yang ada bisa disimpulkan bahwa untuk review score terhadap e commerce sangat baik terlihat reveiw terbanyak berada di angka 5 dengan total lebih dari 60000 review

# %% [markdown]
# ### Dimana letak pembeli terbanyak ?

# %%
other_state_geolocation = data['geo'].groupby(['geolocation_zip_code_prefix'])['geolocation_state'].nunique().reset_index(name='count')
other_state_geolocation[other_state_geolocation['count']>= 2].shape
max_state = data['geo'].groupby(['geolocation_zip_code_prefix','geolocation_state']).size().reset_index(name='count').drop_duplicates(subset = 'geolocation_zip_code_prefix').drop('count',axis=1)

# %%
geolocation_silver = data['geo'].groupby(['geolocation_zip_code_prefix','geolocation_city','geolocation_state'])[['geolocation_lat','geolocation_lng']].median().reset_index()
geolocation_silver = geolocation_silver.merge(max_state,on=['geolocation_zip_code_prefix','geolocation_state'],how='inner')

# %%
customers_silver = customers_df.merge(geolocation_silver,left_on='customer_zip_code_prefix',right_on='geolocation_zip_code_prefix',how='inner')

# %%
customers_silver.head(10)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  5dca924cc99eea2dc5ba40d11ec5dd0f  2761fee7f378f0a8d7682d8a3fa07ab1
# 2  661897d4968f1b59bfff74c7eb2eb4fc  d06a495406b79cb8203ea21cc0942f8c
# 3  702b62324327ccba20f1be3465426437  8b3d988f330c1d1c3332ccd440c147b7
# 4  bdf997bae7ca819b0415f5174d6b4302  866755e25db620f8d7e81b351a15bb2f
# 5  48a9965057e1c75ed3a4d511714be18b  2be1bf7d96bccea9775dcd4c5cbde376
# 6  96fbbe8005e67d382b0fc453a288be02  8d153d12b59d763efeb3953822c51862
# 7  7d58157ef9ab184d29d36f009c7ad786  4dd678b3eb5be4a5589f5566ec386e09
# 8  d3c09791fc7ede919353f0488a3375a6  422b5643b144b86f0168965efd90c219
# 9  29e139325c0dac2e5a95c165699b68c3  d0fa1eaf9648a765ed0458e85186703d
#
#    customer_zip_code_prefix customer_city customer_state  \
# 0                     14409        franca             SP
# 1                     14409        franca             SP
# ...

# %%
customers_silver = customers_silver.drop_duplicates('order_id')

# %%
customers_silver.to_csv("drive/MyDrive/Bangkit/peta.csv", index=False)

# %%
def plot_brazil_map(data):
    brazil = mpimg.imread(urllib.request.urlopen('https://i.pinimg.com/originals/3a/0c/e1/3a0ce18b3c842748c255bc0aa445ad41.jpg'),'jpg')
    ax = data.plot(kind="scatter", x="geolocation_lng", y="geolocation_lat", figsize=(10,10), alpha=0.3,s=0.3,c='maroon')
    plt.axis('off')
    plt.imshow(brazil, extent=[-73.98283055, -33.8,-33.75116944,5.4])
    plt.show()

# %%
plot_brazil_map(customers_silver.drop_duplicates(subset='customer_unique_id'))

# %% [markdown]
# dilihat dari geo lokasi ternyata pembeli terbanyak berada di bagian tenggara dan selatan

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ##produk apa yang memiliki penjualan tertinggi dan terendah ?
#
# - Kategori produk yang paling diminati oleh pelanggan adalah "bed_bath_table" dengan penjualan yang hampir menyentuh 12000 unit. Sedangkan produk "security and services" merupakan produk yang memiliki penjualan paling rendah tidak sampai 5.

# %% [markdown]
# ##Bagaimana tingkat kepuasan pembeli ?
# - seperti yang tergambar dalam visualisasi data. Banyak pelanggan memberikan rating 5, dengan rating 4 berada di posisi kedua terbanyak hal itu menunjukan bahwa tingkat kepuasan terhadap layanan sangat tinggi.

# %% [markdown]
# ##Dimana letak gegrafis pembeli terbanyak ?
#
# - Berdasarkan geo lokasi yang tergambar pembeli terbanyak terdapat dibagian tenggara dan selatan yaitu berada di kota-kota yang besar São Paulo, Rio de Janeiro, Porto Alegre, dll.
